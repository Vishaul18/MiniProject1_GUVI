# %%
# %pip install pandas
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
#data has been loaded to python using pandas and printed the nead, info and stastics of the dataset
df = pd.read_csv('/workspaces/MiniProject1_GUVI/Uber_Eats_data.csv')
print(df.head())
print(df.describe())
print(df.info())
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#                               phone      location            rest_type  \
# 0    080 42297555\r\n+91 9743772233  Banashankari        Casual Dining
# 1                      080 41714161  Banashankari        Casual Dining
# 2                    +91 9663487993  Banashankari  Cafe, Casual Dining
# 3                    +91 9620009302  Banashankari          Quick Bites
# 4  +91 8026612447\r\n+91 9901210005  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# ...

# %%
#droping the column phone as it is not relevant for the analysis
df = df.drop(columns='phone')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         23193 non-null  str
#  1   online_order                 23193 non-null  str
#  2   book_table                   23193 non-null  str
#  3   rate                         23193 non-null  str
#  4   votes                        23193 non-null  int64
#  5   location                     23193 non-null  str
#  6   rest_type                    23193 non-null  str
#  7   dish_liked                   23193 non-null  str
#  8   cuisines                     23193 non-null  str
#  9   approx_cost(for two people)  23193 non-null  str
#  10  listed_in(type)              23193 non-null  str
#  11  listed_in(city)              23193 non-null  str
# dtypes: int64(1), str(11)
# memory usage: 2.1 MB

# %%
#making the column names in small and removing unwanted spaces
df.columns = df.columns.str.lower().str.strip()

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'location',
#        'rest_type', 'dish_liked', 'cuisines', 'approx_cost(for two people)',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='str')

# %%
#checking the missing values in name column
df.name.isnull().sum()
# Out:
# np.int64(0)

# %%
#changing name column in lowercase and removing unwanted spaces
df.name = df.name.str.lower().str.strip()

# %%
#counting the number of calues in name column
df.name.value_counts()
# Out:
# name
# onesta               85
# empire restaurant    69
# kfc                  59
# mcdonald's           57
# pizza hut            56
#                      ..
# hunan express         1
# bao & grills          1
# gongura               1
# tuk-tuk               1
# fujian express        1
# Name: count, Length: 3152, dtype: int64

# %%
df.name.unique()
# Out:
# <StringArray>
# [                                                 'jalsa',
#                                          'spice elephant',
#                                         'san churro cafe',
#                                   'addhuri udupi bhojana',
#                                           'grand village',
#                                         'timepass dinner',
#                                                  'onesta',
#                                          'penthouse cafe',
#                                               'smacznego',
#      'cafãâãâãâãâãâãâãâãâ© down the alley',
#  ...
#                                        'squeez juice bar',
#                                        'nalaas aapakadai',
#                                        'mothi restaurant',
#                                                  'naga's',
#                                           'hunan express',
#                                            'bao & grills',
# ...

# %%
#checking null values in online_order column
df.online_order.isnull().sum()
# Out:
# np.int64(0)

# %%
#counting the values in online_order column
df.online_order.value_counts()
# Out:
# online_order
# Yes    16358
# No      6835
# Name: count, dtype: int64

# %%
#checking null values in book_table column
df.book_table.isnull().sum()
# Out:
# np.int64(0)

# %%
#counting values in the book_table column
df.book_table.value_counts()
# Out:
# book_table
# No     17071
# Yes     6122
# Name: count, dtype: int64

# %%
#checking null values in rate column
df.rate.isnull().sum()
# Out:
# np.int64(0)

# %%
df.rate.value_counts()
# Out:
# rate
# 3.9/5     1689
# 3.9 /5    1549
# 4.0/5     1469
# 4.1/5     1398
# 4.0 /5    1391
#           ...
# 2.2 /5       7
# 2.0 /5       7
# 2.0/5        4
# 1.8 /5       3
# 1.8/5        2
# Name: count, Length: 63, dtype: int64

# %%
df.rate.unique()
# Out:
# <StringArray>
# [ '4.1/5',  '3.8/5',  '3.7/5',  '4.6/5',  '4.0/5',  '4.2/5',  '3.9/5',
#   '3.0/5',  '3.6/5',  '2.8/5',  '4.4/5',  '3.1/5',  '4.3/5',  '2.6/5',
#   '3.3/5',  '3.5/5', '3.8 /5',  '3.2/5',  '4.5/5',  '2.5/5',  '2.9/5',
#   '3.4/5',  '2.7/5',  '4.7/5',    'NEW',  '2.4/5',  '2.2/5',  '2.3/5',
#   '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5', '2.9 /5', '2.7 /5',
#  '2.5 /5', '2.6 /5', '4.5 /5', '4.3 /5', '3.7 /5', '4.4 /5',  '4.9/5',
#   '2.1/5',  '2.0/5',  '1.8/5', '3.4 /5', '3.6 /5', '3.3 /5', '4.6 /5',
#  '4.9 /5', '3.2 /5', '3.0 /5', '2.8 /5', '3.5 /5', '3.1 /5', '4.8 /5',
#  '2.3 /5', '4.7 /5', '2.4 /5', '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5']
# Length: 63, dtype: str

# %%
df.rate.isnull().sum()
# Out:
# np.int64(0)

# %%
df.rate.value_counts(0)
# Out:
# rate
# 3.9/5     1689
# 3.9 /5    1549
# 4.0/5     1469
# 4.1/5     1398
# 4.0 /5    1391
#           ...
# 2.2 /5       7
# 2.0 /5       7
# 2.0/5        4
# 1.8 /5       3
# 1.8/5        2
# Name: count, Length: 63, dtype: int64

# %%
df.rate.unique()
# Out:
# <StringArray>
# [ '4.1/5',  '3.8/5',  '3.7/5',  '4.6/5',  '4.0/5',  '4.2/5',  '3.9/5',
#   '3.0/5',  '3.6/5',  '2.8/5',  '4.4/5',  '3.1/5',  '4.3/5',  '2.6/5',
#   '3.3/5',  '3.5/5', '3.8 /5',  '3.2/5',  '4.5/5',  '2.5/5',  '2.9/5',
#   '3.4/5',  '2.7/5',  '4.7/5',    'NEW',  '2.4/5',  '2.2/5',  '2.3/5',
#   '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5', '2.9 /5', '2.7 /5',
#  '2.5 /5', '2.6 /5', '4.5 /5', '4.3 /5', '3.7 /5', '4.4 /5',  '4.9/5',
#   '2.1/5',  '2.0/5',  '1.8/5', '3.4 /5', '3.6 /5', '3.3 /5', '4.6 /5',
#  '4.9 /5', '3.2 /5', '3.0 /5', '2.8 /5', '3.5 /5', '3.1 /5', '4.8 /5',
#  '2.3 /5', '4.7 /5', '2.4 /5', '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5']
# Length: 63, dtype: str

# %%
(df.rate=='NEW').sum()
# Out:
# np.int64(147)

# %%
df = df[df['rate'] != 'NEW']
